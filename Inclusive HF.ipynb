# %%
import matplotlib.pyplot as plt
import glob
import numpy as np
import pandas as pd
import math
import seaborn as sns

import sys, os, platform, glob, zipfile, math, shutil, random, gc, json, re, pathlib
from scipy.optimize import curve_fit
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, confusion_matrix, roc_curve, precision_recall_curve
from sklearn.utils.class_weight import compute_class_weight
from sklearn.svm import SVC

from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import LearningCurveDisplay, ShuffleSplit

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/ml files/updatedmuon.csv'

df = pd.read_csv(file_path)

print(df)
# Out:
#        collisionID  trackID     mcID      eta        pt          p      phi  \
# 0              111       -1    88367 -3.16496  0.243115   2.884550 -2.59080
# 1              111        0    88367  2.72339  0.115458   0.883115  6.49523
# 2              125       -1   102667 -3.41393  0.858880  13.062400  2.80120
# 3              125        2   102667 -3.43907  0.996715  15.543900  2.77976
# 4              168        5   133004 -2.81062  0.592036   4.937700 -2.29163
# ...            ...      ...      ...      ...       ...        ...      ...
# 88156         1694    11870  2165162 -2.53649  1.267230   8.056050 -1.19439
# 88157         1694    11870  2165162 -2.26606  2.343080  11.416700 -2.10517
# 88158         1694    11870  2165162 -2.20876  1.795700   8.273080 -1.53141
# 88159         1694    11870  2165162 -2.49586  1.298260   7.928870 -1.22032
# 88160         1694       -2  2168601 -2.99374  0.450407   4.506400 -1.57832
#
#        motherPDG  nClusters  trackType      pDca           chi2  \
# 0            211         11          3   76.7159       0.515625
# 1            211         11          0   76.7159  370688.000000
# 2            321         12          3   44.9307       0.144531
# 3            321         12          0   44.9307      37.000000
# 4            211         10          2   58.2282    1000.000000
# ...          ...        ...        ...       ...            ...
# 88156        411         10          0  110.6710    2768.000000
# 88157        411         10          0  110.6710   24960.000000
# 88158        411         10          0  110.6710     254.000000
# 88159        411         10          0  110.6710    1880.000000
# 88160        421          9          4   65.1975       0.128906
#
#        chi2MatchMCHMID     rabs  isPrompt   tracktime  sign
# 0             1.218750  28.8967         1   12.479266     1
# 1             1.218750  28.8967         1   12.479266    -1
# 2             0.554688  31.1311         1  286.939819     1
# 3             0.554688  31.1311         1  286.939819     1
# 4            -1.000000  45.7409         1  723.559570    -1
# ...                ...      ...       ...         ...   ...
# 88156         0.449219  81.7858         1 -212.064133    -1
# 88157         0.449219  81.7858         1 -212.064133     1
# 88158         0.449219  81.7858         1 -212.064133    -1
# 88159         0.449219  81.7858         1 -212.064133    -1
# 88160        -1.000000  58.4170         1  898.248352     1
#
# [88161 rows x 17 columns]

# %%
track_df = df[(df['trackType'] == 3)]
cut_df = track_df[(track_df['p'] > 4) & (track_df['eta'] >= -4) & (track_df['eta'] <= -2.5) & (track_df['pt'] > 0.5)] #consists of the chi2, track type & momentum cuts needed

filter_df = cut_df[(cut_df['chi2'] <= 10)]

# %%
cut_df.to_csv('cutsapplied(nochi2).csv', index=False)
cut_df.to_csv('/content/drive/MyDrive/ml files/cutsapplied(nochi2).csv', index=False)

# %%
filter_df.to_csv('cutsapplied.csv', index=False)
filter_df.to_csv('/content/drive/MyDrive/ml files/cutsapplied.csv', index=False)

# %%
signalD = [abs(411), abs(421), abs(431), abs(4122), abs(4232), abs(4132)]
signalB = [abs(521), abs(511), abs(531), abs(5232), abs(5132), abs(5122)]
signalPDG = [abs(411), abs(421), abs(431), abs(4122), abs(4232), abs(4132), abs(521), abs(511), abs(531), abs(5232), abs(5132), abs(5122)]

# %%
label = []

for index, row in cut_df.iterrows():
  pdg = abs(row['motherPDG'])
  if pdg in signalPDG:
    label.append("s")   # B meson signal
  else:
    label.append("b")   # background

cut_df['label'] = label
# Out:
# /tmp/ipython-input-3370958908.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['label'] = label

# %%
cut_df
# Out:
#        collisionID  trackID     mcID      eta        pt         p       phi  \
# 2              125       -1   102667 -3.41393  0.858880  13.06240  2.801200
# 6              218       -1   171002 -2.93607  0.560673   5.29689  1.075610
# 8              252       -1   197209 -3.73895  0.510914  10.74910  0.096842
# 20             719       -5   540836 -3.46161  0.574716   9.16664 -0.345634
# 34             877       -5   657418 -2.95560  0.560175   5.39596  2.508450
# ...            ...      ...      ...      ...       ...       ...       ...
# 88090         1684       -2  2155308 -2.86598  0.821995   7.24307 -1.208640
# 88091         1684       -2  2155794 -3.73386  0.546972  11.44930  2.459840
# 88119         1688       -2  2159871 -3.51072  0.830579  13.91310 -1.892480
# 88125         1689       -2  2161464 -3.29699  0.758238  10.26200  1.238660
# 88143         1694       -2  2167180 -2.89710  0.872603   7.93056  0.819328
#
#        motherPDG  nClusters  trackType      pDca      chi2  chi2MatchMCHMID  \
# 2            321         12          3   44.9307  0.144531         0.554688
# 6            321         10          3  140.5290  0.210938         1.062500
# 8            321         10          3   51.1675  0.232422         1.304690
# 20           321         12          3  134.2360  0.092773         0.703125
# 34           211         10          3  105.3500  0.173828         1.203120
# ...          ...        ...        ...       ...       ...              ...
# 88090        411         10          3   16.0551  0.120605         0.894531
# 88091        421          9          3   40.6495  0.129883         0.511719
# 88119        431          7          3   30.4072  0.375000         0.585938
# 88125        431         14          3   59.5527  0.102539         1.593750
# 88143       4122         12          3   41.8271  0.080566         0.730469
#
#           rabs  isPrompt   tracktime  sign label
# 2      31.1311         1  286.939819     1     b
# 6      31.8958         1  736.044556    -1     b
# 8      26.5259         1  910.683838    -1     b
# 20     18.2902         1  611.293945     1     b
# 34     36.8680         0   12.463362    -1     b
# ...        ...       ...         ...   ...   ...
# 88090  56.2943         1   37.463413     1     s
# 88091  26.3077         1  910.650940    -1     s
# 88119  29.1006         1  486.548035     1     s
# 88125  33.4272         1  511.483124     1     s
# 88143  56.6216         1  187.123367    -1     s
#
# [10290 rows x 18 columns]

# %%
pdg = cut_df['motherPDG']

pdg.value_counts()
# Out:
# motherPDG
# 211     3457
# 321     1812
# 421     1337
# 411     1214
# 521      824
# 511      808
# 431      290
# 531      162
# 5122      72
# 4122      66
# 223       54
# 221       39
# 15        33
# 443       29
# 113       21
# 130       18
# 333       14
# 5232       9
# 4132       8
# 4232       8
# 5132       7
# 2212       6
# 331        2
# Name: count, dtype: int64

# %%
l = cut_df['label']
l.value_counts()
# Out:
# label
# b    5485
# s    4805
# Name: count, dtype: int64

# %%
print(cut_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10290 entries, 2 to 88143
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   collisionID      10290 non-null  int64
#  1   trackID          10290 non-null  int64
#  2   mcID             10290 non-null  int64
#  3   eta              10290 non-null  float64
#  4   pt               10290 non-null  float64
#  5   p                10290 non-null  float64
#  6   phi              10290 non-null  float64
#  7   motherPDG        10290 non-null  int64
#  8   nClusters        10290 non-null  int64
#  9   trackType        10290 non-null  int64
#  10  pDca             10290 non-null  float64
#  11  chi2             10290 non-null  float64
#  12  chi2MatchMCHMID  10290 non-null  float64
#  13  rabs             10290 non-null  float64
#  14  isPrompt         10290 non-null  int64
#  15  tracktime        10290 non-null  float64
#  16  sign             10290 non-null  int64
#  17  label            10290 non-null  object
# dtypes: float64(9), int64(8), object(1)
# memory usage: 1.5+ MB
# None

# %%
cut_df['y'] = (cut_df["label"] == "s").astype(int)

y = cut_df['y'].to_numpy()
# Out:
# /tmp/ipython-input-3848919311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['y'] = (cut_df["label"] == "s").astype(int)

# %%
weight = compute_class_weight(class_weight="balanced", classes=np.unique(y), y=y)
print(weight)
# Out:
# [0.93801276 1.07075963]

# %%
cut_df['w'] = np.where(cut_df['y'] == 1, weight[1], weight[0])
w = cut_df['w']
# Out:
# /tmp/ipython-input-4139032214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['w'] = np.where(cut_df['y'] == 1, weight[1], weight[0])

# %%
w.value_counts()
# Out:
# w
# 0.938013    5485
# 1.070760    4805
# Name: count, dtype: int64

# %%
cut_df
# Out:
#        collisionID  trackID     mcID      eta        pt         p       phi  \
# 2              125       -1   102667 -3.41393  0.858880  13.06240  2.801200
# 6              218       -1   171002 -2.93607  0.560673   5.29689  1.075610
# 8              252       -1   197209 -3.73895  0.510914  10.74910  0.096842
# 20             719       -5   540836 -3.46161  0.574716   9.16664 -0.345634
# 34             877       -5   657418 -2.95560  0.560175   5.39596  2.508450
# ...            ...      ...      ...      ...       ...       ...       ...
# 88090         1684       -2  2155308 -2.86598  0.821995   7.24307 -1.208640
# 88091         1684       -2  2155794 -3.73386  0.546972  11.44930  2.459840
# 88119         1688       -2  2159871 -3.51072  0.830579  13.91310 -1.892480
# 88125         1689       -2  2161464 -3.29699  0.758238  10.26200  1.238660
# 88143         1694       -2  2167180 -2.89710  0.872603   7.93056  0.819328
#
#        motherPDG  nClusters  trackType      pDca      chi2  chi2MatchMCHMID  \
# 2            321         12          3   44.9307  0.144531         0.554688
# 6            321         10          3  140.5290  0.210938         1.062500
# 8            321         10          3   51.1675  0.232422         1.304690
# 20           321         12          3  134.2360  0.092773         0.703125
# 34           211         10          3  105.3500  0.173828         1.203120
# ...          ...        ...        ...       ...       ...              ...
# 88090        411         10          3   16.0551  0.120605         0.894531
# 88091        421          9          3   40.6495  0.129883         0.511719
# 88119        431          7          3   30.4072  0.375000         0.585938
# 88125        431         14          3   59.5527  0.102539         1.593750
# 88143       4122         12          3   41.8271  0.080566         0.730469
#
#           rabs  isPrompt   tracktime  sign label  y         w
# 2      31.1311         1  286.939819     1     b  0  0.938013
# 6      31.8958         1  736.044556    -1     b  0  0.938013
# 8      26.5259         1  910.683838    -1     b  0  0.938013
# 20     18.2902         1  611.293945     1     b  0  0.938013
# 34     36.8680         0   12.463362    -1     b  0  0.938013
# ...        ...       ...         ...   ...   ... ..       ...
# 88090  56.2943         1   37.463413     1     s  1  1.070760
# 88091  26.3077         1  910.650940    -1     s  1  1.070760
# 88119  29.1006         1  486.548035     1     s  1  1.070760
# 88125  33.4272         1  511.483124     1     s  1  1.070760
# 88143  56.6216         1  187.123367    -1     s  1  1.070760
#
# [10290 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Exclude columns not to be used as input features
FEATURE_EXCLUDE = ['trackType', 'motherPDG', 'mcID', 'trackID', 'collisionID','label', 'y', 'w', 'sign']
features = [c for c in cut_df.columns if c not in FEATURE_EXCLUDE]

# %%
x_raw = cut_df[features].copy()

# %%
x_raw
# Out:
#            eta        pt         p       phi  nClusters      pDca      chi2  \
# 2     -3.41393  0.858880  13.06240  2.801200         12   44.9307  0.144531
# 6     -2.93607  0.560673   5.29689  1.075610         10  140.5290  0.210938
# 8     -3.73895  0.510914  10.74910  0.096842         10   51.1675  0.232422
# 20    -3.46161  0.574716   9.16664 -0.345634         12  134.2360  0.092773
# 34    -2.95560  0.560175   5.39596  2.508450         10  105.3500  0.173828
# ...        ...       ...       ...       ...        ...       ...       ...
# 88090 -2.86598  0.821995   7.24307 -1.208640         10   16.0551  0.120605
# 88091 -3.73386  0.546972  11.44930  2.459840          9   40.6495  0.129883
# 88119 -3.51072  0.830579  13.91310 -1.892480          7   30.4072  0.375000
# 88125 -3.29699  0.758238  10.26200  1.238660         14   59.5527  0.102539
# 88143 -2.89710  0.872603   7.93056  0.819328         12   41.8271  0.080566
#
#        chi2MatchMCHMID     rabs  isPrompt   tracktime
# 2             0.554688  31.1311         1  286.939819
# 6             1.062500  31.8958         1  736.044556
# 8             1.304690  26.5259         1  910.683838
# 20            0.703125  18.2902         1  611.293945
# 34            1.203120  36.8680         0   12.463362
# ...                ...      ...       ...         ...
# 88090         0.894531  56.2943         1   37.463413
# 88091         0.511719  26.3077         1  910.650940
# 88119         0.585938  29.1006         1  486.548035
# 88125         1.593750  33.4272         1  511.483124
# 88143         0.730469  56.6216         1  187.123367
#
# [10290 rows x 11 columns]

# %%
imputer = SimpleImputer(strategy="median")
x_imputed = imputer.fit_transform(x_raw)

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_imputed)

#xb_train, xb_test, yb_train, yb_test, wb_train, wb_test = train_test_split(xb_scaled, yb, wb, test_size=0.2, random_state=42, stratify=yb)

x_train, x_test, y_train, y_test, w_train, w_test = train_test_split(x_scaled, y, w, test_size=0.2, random_state=42, stratify=y)

print("Num features:", len(features))
x_train.shape, x_test.shape
# Out:
# Num features: 11
# ((8232, 11), (2058, 11))

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=25, random_state=42)
random_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=25, random_state=42)

# %%
importances = random_forest.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(10,6))
bars = plt.bar(range(x_raw.shape[1]), importances[indices], color='red', alpha=0.8, linewidth=1)

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f"{height:.2f}", ha="center", va="bottom", size=8)

plt.ylabel("Importance")
plt.xticks(range(x_raw.shape[1]), np.array(x_raw.columns)[indices], rotation=90, size=12)
# Out:
# ([<matplotlib.axis.XTick at 0x7ad2d564bf80>,
#   <matplotlib.axis.XTick at 0x7ad2d5512540>,
#   <matplotlib.axis.XTick at 0x7ad2d53a0f80>,
#   <matplotlib.axis.XTick at 0x7ad2d53a1b50>,
#   <matplotlib.axis.XTick at 0x7ad2d53a2660>,
#   <matplotlib.axis.XTick at 0x7ad2d53a3140>,
#   <matplotlib.axis.XTick at 0x7ad2d53a3b60>,
#   <matplotlib.axis.XTick at 0x7ad2d53a1d60>,
#   <matplotlib.axis.XTick at 0x7ad2d53e4620>,
#   <matplotlib.axis.XTick at 0x7ad2d53e5100>,
#   <matplotlib.axis.XTick at 0x7ad2d53e5b50>],
#  [Text(0, 0, 'pt'),
#   Text(1, 0, 'p'),
#   Text(2, 0, 'pDca'),
#   Text(3, 0, 'rabs'),
#   Text(4, 0, 'eta'),
#   Text(5, 0, 'chi2'),
#   Text(6, 0, 'phi'),
#   Text(7, 0, 'tracktime'),
#   Text(8, 0, 'chi2MatchMCHMID'),
#   Text(9, 0, 'isPrompt'),
#   Text(10, 0, 'nClusters')])

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers

keras.backend.clear_session()

def make_mlp(input_dim, hidden=[90, 80, 60, 55, 35], drop=0.25, l2=0.0):
    """
    Build a binary-classification MLP.

    Args:
        input_dim (int): number of input features (columns) after preprocessing.
        hidden (list[int]): how many neurons (units) to put in each hidden layer.
                            Example [256,128,64] means 3 hidden layers with those widths.
        drop (float): dropout rate (0.0–0.5 typical). Dropout randomly turns off a
                      fraction of neurons during training to reduce overfitting.
        l2 (float): L2 weight regularization strength (a small penalty on large weights).
                    Helps keep the model simpler and more generalizable.

    Returns:
        keras.Model: a compiled model ready to train with model.fit(...)
    """

    # ----- 1) Define the input “place holder” -----
    # Shape=(input_dim,) means the model expects a 1D vector of length input_dim for each row.
    inputs = keras.Input(shape=(input_dim,), name="features")

    # We'll wire layers onto this tensor "x". We start with x=inputs.
    x = inputs

    # ----- 2) Hidden layers (the actual “learning” happens here) -----
    # We loop over the list "hidden" so it’s easy to change depth/width from the function call.
    for i, h in enumerate(hidden, start=1):
        # Dense = fully connected layer. 'h' controls how many neurons (capacity).
        # activation='relu' is a standard nonlinearity that helps the network learn complex patterns.
        # kernel_regularizer adds the L2 penalty (weight decay) to fight overfitting.
        x = layers.Dense(
            h,
            activation="relu",
            kernel_regularizer=regularizers.l2(l2),
            name=f"dense_{i}"
        )(x)

        # Batch Normalization stabilizes and speeds up training by normalizing activations
        # inside the network (per mini-batch). This often allows slightly higher learning rates.
        x = layers.BatchNormalization(name=f"bn_{i}")(x)

        # Dropout randomly zeroes out a fraction `drop` of activations during training.
        # Think of it as creating slightly different sub-networks each step, which prevents
        # the model from relying too heavily on any single path (“co-adaptation”).
        x = layers.Dropout(drop, name=f"drop_{i}")(x)

    # ----- 3) Output layer -----
    # We have a **binary** classification problem (signal vs background),
    # so we produce ONE number in [0,1] using 'sigmoid'.
    # This can be interpreted as P(y=1 | x) = probability of signal.
    outputs = layers.Dense(1, activation="sigmoid", name="logit")(x)

    # ----- 4) Build the model graph -----
    model = keras.Model(inputs, outputs, name="mlp_higgs")

    # ----- 5) Choose optimizer, loss, and metrics -----
    # Optimizer: Adam is a good default that adapts the learning rate during training.
    # Loss: binary cross-entropy is the standard for binary classification.
    # Metrics:
    #   - AUC (ROC-AUC): threshold-free measure of ranking quality.
    #   - Precision & Recall: computed at a default threshold (0.5) — useful but threshold-dependent.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.AUC(name="auc"),
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall"),
        ],
    )

    return model

# ----- 6) Create the model -----
# X_train.shape[1] is “how many feature columns do we have?”
# We use 3 hidden layers with widths 256 → 128 → 64, 20% dropout, tiny L2 penalty.
mlp = make_mlp(
    input_dim=x_train.shape[1],
    hidden=[90, 80, 60, 55, 35],
    drop=0.25,
    l2=1e-10 #1e-6
)

# Show a summary table of the layers, shapes, and parameter counts.
mlp.summary()
# Out:
# Model: "mlp_higgs"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ features (InputLayer)           │ (None, 11)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 90)             │         1,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 90)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_1 (Dropout)                │ (None, 90)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 80)             │         7,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 80)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_2 (Dropout)                │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 60)             │         4,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_3 (BatchNormalization)       │ (None, 60)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_3 (Dropout)                │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 55)             │         3,355 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_4 (BatchNormalization)       │ (None, 55)             │           220 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_4 (Dropout)                │ (None, 55)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 35)             │         1,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_5 (BatchNormalization)       │ (None, 35)             │           140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_5 (Dropout)                │ (None, 35)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ logit (Dense)                   │ (None, 1)              │            36 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,851 (77.54 KB)
#  Trainable params: 19,211 (75.04 KB)
#  Non-trainable params: 640 (2.50 KB)

# %%
history = mlp.fit(
    x_train, y_train,
    sample_weight=w_train,              # <-- important: use sample weights
    validation_data=(x_test, y_test, w_test),
    epochs=50,
    batch_size=100,
    verbose=1
)
# Out:
# Epoch 1/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - auc: 0.6103 - loss: 0.7818 - precision: 0.5442 - recall: 0.5615 - val_auc: 0.7772 - val_loss: 0.6302 - val_precision: 0.8591 - val_recall: 0.3236
# Epoch 2/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - auc: 0.7219 - loss: 0.6283 - precision: 0.6266 - recall: 0.6325 - val_auc: 0.7954 - val_loss: 0.5795 - val_precision: 0.7930 - val_recall: 0.4984
# Epoch 3/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7363 - loss: 0.6144 - precision: 0.6406 - recall: 0.6410 - val_auc: 0.8006 - val_loss: 0.5480 - val_precision: 0.7372 - val_recall: 0.6597
# Epoch 4/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7520 - loss: 0.5980 - precision: 0.6502 - recall: 0.6647 - val_auc: 0.8073 - val_loss: 0.5373 - val_precision: 0.7183 - val_recall: 0.6951
# Epoch 5/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7587 - loss: 0.5893 - precision: 0.6499 - recall: 0.6681 - val_auc: 0.8125 - val_loss: 0.5291 - val_precision: 0.7362 - val_recall: 0.6795
# Epoch 6/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7798 - loss: 0.5642 - precision: 0.6820 - recall: 0.6796 - val_auc: 0.8139 - val_loss: 0.5259 - val_precision: 0.7343 - val_recall: 0.7045
# Epoch 7/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7733 - loss: 0.5700 - precision: 0.6751 - recall: 0.6786 - val_auc: 0.8153 - val_loss: 0.5238 - val_precision: 0.7229 - val_recall: 0.7138
# Epoch 8/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7912 - loss: 0.5568 - precision: 0.6907 - recall: 0.7107 - val_auc: 0.8158 - val_loss: 0.5233 - val_precision: 0.7242 - val_recall: 0.7159
# Epoch 9/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7888 - loss: 0.5570 - precision: 0.6944 - recall: 0.6868 - val_auc: 0.8152 - val_loss: 0.5243 - val_precision: 0.7250 - val_recall: 0.7159
# Epoch 10/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7913 - loss: 0.5560 - precision: 0.7000 - recall: 0.6765 - val_auc: 0.8175 - val_loss: 0.5212 - val_precision: 0.7286 - val_recall: 0.7097
# Epoch 11/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7932 - loss: 0.5491 - precision: 0.7001 - recall: 0.6832 - val_auc: 0.8179 - val_loss: 0.5208 - val_precision: 0.7257 - val_recall: 0.7211
# Epoch 12/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8024 - loss: 0.5429 - precision: 0.7090 - recall: 0.6961 - val_auc: 0.8177 - val_loss: 0.5210 - val_precision: 0.7219 - val_recall: 0.7159
# Epoch 13/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.8018 - loss: 0.5378 - precision: 0.6938 - recall: 0.7082 - val_auc: 0.8167 - val_loss: 0.5227 - val_precision: 0.7162 - val_recall: 0.7170
# Epoch 14/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7967 - loss: 0.5479 - precision: 0.7148 - recall: 0.6931 - val_auc: 0.8171 - val_loss: 0.5223 - val_precision: 0.7040 - val_recall: 0.7451
# Epoch 15/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8037 - loss: 0.5406 - precision: 0.7073 - recall: 0.7068 - val_auc: 0.8183 - val_loss: 0.5203 - val_precision: 0.7246 - val_recall: 0.7201
# Epoch 16/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7913 - loss: 0.5516 - precision: 0.7106 - recall: 0.6863 - val_auc: 0.8182 - val_loss: 0.5200 - val_precision: 0.7207 - val_recall: 0.7222
# Epoch 17/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.8019 - loss: 0.5409 - precision: 0.7126 - recall: 0.6863 - val_auc: 0.8183 - val_loss: 0.5199 - val_precision: 0.7090 - val_recall: 0.7326
# Epoch 18/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.7964 - loss: 0.5493 - precision: 0.7093 - recall: 0.7130 - val_auc: 0.8189 - val_loss: 0.5192 - val_precision: 0.7294 - val_recall: 0.7180
# Epoch 19/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.7966 - loss: 0.5498 - precision: 0.7103 - recall: 0.7005 - val_auc: 0.8198 - val_loss: 0.5182 - val_precision: 0.7177 - val_recall: 0.7274
# Epoch 20/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.8047 - loss: 0.5377 - precision: 0.7085 - recall: 0.7075 - val_auc: 0.8195 - val_loss: 0.5184 - val_precision: 0.7052 - val_recall: 0.7367
# Epoch 21/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8033 - loss: 0.5400 - precision: 0.7114 - recall: 0.7015 - val_auc: 0.8202 - val_loss: 0.5180 - val_precision: 0.7236 - val_recall: 0.7190
# Epoch 22/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7977 - loss: 0.5486 - precision: 0.7247 - recall: 0.6861 - val_auc: 0.8211 - val_loss: 0.5171 - val_precision: 0.7269 - val_recall: 0.7118
# Epoch 23/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8105 - loss: 0.5293 - precision: 0.7199 - recall: 0.6982 - val_auc: 0.8210 - val_loss: 0.5195 - val_precision: 0.7051 - val_recall: 0.7565
# Epoch 24/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8064 - loss: 0.5364 - precision: 0.7071 - recall: 0.7047 - val_auc: 0.8210 - val_loss: 0.5170 - val_precision: 0.7144 - val_recall: 0.7263
# Epoch 25/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8044 - loss: 0.5377 - precision: 0.7100 - recall: 0.6926 - val_auc: 0.8207 - val_loss: 0.5176 - val_precision: 0.7108 - val_recall: 0.7315
# Epoch 26/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8148 - loss: 0.5270 - precision: 0.7228 - recall: 0.7139 - val_auc: 0.8210 - val_loss: 0.5183 - val_precision: 0.7227 - val_recall: 0.7242
# Epoch 27/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8056 - loss: 0.5363 - precision: 0.7246 - recall: 0.7045 - val_auc: 0.8210 - val_loss: 0.5177 - val_precision: 0.7157 - val_recall: 0.7284
# Epoch 28/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8013 - loss: 0.5405 - precision: 0.7066 - recall: 0.7092 - val_auc: 0.8216 - val_loss: 0.5164 - val_precision: 0.7111 - val_recall: 0.7378
# Epoch 29/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8052 - loss: 0.5365 - precision: 0.7101 - recall: 0.6959 - val_auc: 0.8214 - val_loss: 0.5172 - val_precision: 0.7160 - val_recall: 0.7294
# Epoch 30/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8013 - loss: 0.5424 - precision: 0.7186 - recall: 0.6983 - val_auc: 0.8213 - val_loss: 0.5174 - val_precision: 0.7187 - val_recall: 0.7284
# Epoch 31/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8037 - loss: 0.5381 - precision: 0.7177 - recall: 0.7018 - val_auc: 0.8214 - val_loss: 0.5173 - val_precision: 0.7181 - val_recall: 0.7315
# Epoch 32/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8072 - loss: 0.5345 - precision: 0.7211 - recall: 0.6961 - val_auc: 0.8205 - val_loss: 0.5181 - val_precision: 0.7246 - val_recall: 0.7201
# Epoch 33/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8096 - loss: 0.5295 - precision: 0.7203 - recall: 0.7065 - val_auc: 0.8210 - val_loss: 0.5171 - val_precision: 0.6991 - val_recall: 0.7544
# Epoch 34/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8065 - loss: 0.5354 - precision: 0.7074 - recall: 0.7076 - val_auc: 0.8217 - val_loss: 0.5162 - val_precision: 0.7094 - val_recall: 0.7492
# Epoch 35/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.8112 - loss: 0.5287 - precision: 0.7111 - recall: 0.7208 - val_auc: 0.8217 - val_loss: 0.5174 - val_precision: 0.7318 - val_recall: 0.7097
# Epoch 36/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - auc: 0.8129 - loss: 0.5285 - precision: 0.7295 - recall: 0.6996 - val_auc: 0.8211 - val_loss: 0.5172 - val_precision: 0.7333 - val_recall: 0.7180
# Epoch 37/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.8062 - loss: 0.5362 - precision: 0.7170 - recall: 0.6874 - val_auc: 0.8210 - val_loss: 0.5171 - val_precision: 0.7285 - val_recall: 0.7232
# Epoch 38/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.8052 - loss: 0.5356 - precision: 0.7125 - recall: 0.6989 - val_auc: 0.8208 - val_loss: 0.5169 - val_precision: 0.7203 - val_recall: 0.7263
# Epoch 39/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8115 - loss: 0.5310 - precision: 0.7240 - recall: 0.7114 - val_auc: 0.8206 - val_loss: 0.5179 - val_precision: 0.7136 - val_recall: 0.7284
# Epoch 40/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8094 - loss: 0.5317 - precision: 0.7251 - recall: 0.7057 - val_auc: 0.8203 - val_loss: 0.5175 - val_precision: 0.7203 - val_recall: 0.7263
# Epoch 41/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.8058 - loss: 0.5347 - precision: 0.7147 - recall: 0.6955 - val_auc: 0.8211 - val_loss: 0.5166 - val_precision: 0.7177 - val_recall: 0.7274
# Epoch 42/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8199 - loss: 0.5224 - precision: 0.7308 - recall: 0.7240 - val_auc: 0.8208 - val_loss: 0.5171 - val_precision: 0.7310 - val_recall: 0.7097
# Epoch 43/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8050 - loss: 0.5380 - precision: 0.7013 - recall: 0.7096 - val_auc: 0.8202 - val_loss: 0.5179 - val_precision: 0.7264 - val_recall: 0.7128
# Epoch 44/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.8010 - loss: 0.5407 - precision: 0.7143 - recall: 0.6984 - val_auc: 0.8210 - val_loss: 0.5166 - val_precision: 0.7124 - val_recall: 0.7347
# Epoch 45/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8063 - loss: 0.5349 - precision: 0.7156 - recall: 0.6979 - val_auc: 0.8216 - val_loss: 0.5163 - val_precision: 0.7076 - val_recall: 0.7430
# Epoch 46/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.7996 - loss: 0.5406 - precision: 0.7106 - recall: 0.6964 - val_auc: 0.8208 - val_loss: 0.5166 - val_precision: 0.7152 - val_recall: 0.7263
# Epoch 47/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8098 - loss: 0.5331 - precision: 0.7202 - recall: 0.7064 - val_auc: 0.8215 - val_loss: 0.5166 - val_precision: 0.7100 - val_recall: 0.7336
# Epoch 48/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8098 - loss: 0.5316 - precision: 0.7076 - recall: 0.7150 - val_auc: 0.8217 - val_loss: 0.5169 - val_precision: 0.7237 - val_recall: 0.7222
# Epoch 49/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8090 - loss: 0.5318 - precision: 0.7220 - recall: 0.7032 - val_auc: 0.8225 - val_loss: 0.5151 - val_precision: 0.7160 - val_recall: 0.7399
# Epoch 50/50
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.8179 - loss: 0.5229 - precision: 0.7096 - recall: 0.7261 - val_auc: 0.8216 - val_loss: 0.5160 - val_precision: 0.7227 - val_recall: 0.7242

# %%
h = history.history
plt.figure(figsize=(6,4))
plt.plot(h['auc'], label='train accuracy')
plt.plot(h['val_auc'], label='test accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()

plt.figure(figsize=(6,4))
plt.plot(h['loss'], label='train loss')
plt.plot(h['val_loss'], label='test loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# %%
#WITH WEIGHTS

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, accuracy_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score

proba_test_nn = mlp.predict(x_test, batch_size=2048).ravel()
pred_test_nn_05 = (proba_test_nn >= 0.5).astype(int)


metrics_nn_weighted = {
    "Accuracy": accuracy_score(y_test, pred_test_nn_05, sample_weight= w_test),
    "F1": f1_score(y_test, pred_test_nn_05, sample_weight=w_test),
    "ROC_AUC": roc_auc_score(y_test, proba_test_nn, sample_weight=w_test),
    "ConfusionMatrix": confusion_matrix(y_test, pred_test_nn_05, sample_weight=w_test)
}
metrics_nn_weighted
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# {'Accuracy': 0.740427255489145,
#  'F1': 0.7361578467311626,
#  'ROC_AUC': np.float64(0.8216040909983447),
#  'ConfusionMatrix': array([[778.55059253, 250.44940747],
#         [283.75130073, 745.24869927]])}

# %%
# ROC
fpr, tpr, thresholds = roc_curve(y_test, proba_test_nn, sample_weight= w_test)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"ROC AUC (area = {roc_auc_score(y_test, proba_test_nn, sample_weight= w_test):.3f})")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.legend(); plt.show()

# PR
prec, rec, thr = precision_recall_curve(y_test, proba_test_nn, sample_weight= w_test)
plt.figure(figsize=(6,5))
plt.plot(rec, prec)
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.show()

print("Weighted confusion matrix (threshold=0.5):\n", metrics_nn_weighted["ConfusionMatrix"])
# Out:
# Weighted confusion matrix (threshold=0.5):
#  [[778.55059253 250.44940747]
#  [283.75130073 745.24869927]]

# %%
signal = proba_test_nn[y_test == 1]
background = proba_test_nn[y_test == 0]

plt.figure(figsize=(8,6))

plt.axvline(0.5, color='gray', linestyle='--', linewidth=1)

plt.hist(signal, bins=100, density=True, alpha=0.5, label='Signal (label = 1)', color='red')
plt.hist(background, bins=100, density=True, alpha=0.5, label='Background (label = 0)', color='navy')

plt.xlabel('Predicted Probability')
plt.ylabel('Density')
plt.legend()
#plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
cmweighted = confusion_matrix(y_test, pred_test_nn_05, sample_weight=w_test)

tn, fp, fn, tp = cmweighted.ravel()

print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Positives (TP): {tp}")


cm_percent_weight = cmweighted / cmweighted.sum()

labels = np.array([["{0:.2f}\n{1:.1%}".format(value, cm_percent_weight[i, j])
                    for j, value in enumerate(row)] for i, row in enumerate(cmweighted)])

plt.figure(figsize=(6,5))
sns.heatmap(cmweighted, annot=labels, fmt="", cmap="Reds", cbar=True,
            xticklabels=["Predicted 0","Predicted 1"],
            yticklabels=["True 0","True 1"])


plt.ylabel("True")
plt.xlabel("Predicted")
plt.show()
# Out:
# True Negatives (TN): 778.5505925250783
# False Positives (FP): 250.44940747493078
# False Negatives (FN): 283.7513007284089
# True Positives (TP): 745.2486992715953

# %%
precision = precision_score(y_test, pred_test_nn_05)
recall = recall_score(y_test, pred_test_nn_05)

print(recall)
print(precision)
# Out:
# 0.7242455775234131
# 0.7227414330218068

# %%
#WITHOUT WEIGHTS

# %%
metrics_unweighted = {
    "Accuracy": accuracy_score(y_test, pred_test_nn_05),
    "F1": f1_score(y_test, pred_test_nn_05),
    "ROC_AUC": roc_auc_score(y_test, proba_test_nn),
    "ConfusionMatrix": confusion_matrix(y_test, pred_test_nn_05)
}
metrics_unweighted
# Out:
# {'Accuracy': 0.7414965986394558,
#  'F1': 0.7234927234927235,
#  'ROC_AUC': np.float64(0.8216040909983429),
#  'ConfusionMatrix': array([[830, 267],
#         [265, 696]])}

# %%
# ROC
fpr, tpr, thresholds = roc_curve(y_test, proba_test_nn)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"ROC AUC (area= {roc_auc_score(y_test, proba_test_nn):.3f})")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.legend(); plt.show()

# PR
prec, rec, thr = precision_recall_curve(y_test, proba_test_nn)
plt.figure(figsize=(6,5))
plt.plot(rec, prec)
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.show()

print("Unweighted confusion matrix (threshold=0.5):\n", metrics_unweighted["ConfusionMatrix"])
# Out:
# Unweighted confusion matrix (threshold=0.5):
#  [[830 267]
#  [265 696]]

# %%
cm = confusion_matrix(y_test, pred_test_nn_05)

tn, fp, fn, tp = cm.ravel()

print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Positives (TP): {tp}")


cm_percent = cm / cm.sum()

labels = np.array([["{0:.2f}\n{1:.1%}".format(value, cm_percent[i, j])
                    for j, value in enumerate(row)] for i, row in enumerate(cm)])

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=labels, fmt="", cmap="Reds", cbar=True,
            xticklabels=["Predicted 0","Predicted 1"],
            yticklabels=["True 0","True 1"])

plt.ylabel("True")
plt.xlabel("Predicted")
plt.show()
# Out:
# True Negatives (TN): 830
# False Positives (FP): 267
# False Negatives (FN): 265
# True Positives (TP): 696
