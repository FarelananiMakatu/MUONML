# %%
import matplotlib.pyplot as plt
import glob
import numpy as np
import pandas as pd
import math
import seaborn as sns

import sys, os, platform, glob, zipfile, math, shutil, random, gc, json, re, pathlib
from scipy.optimize import curve_fit
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score

from sklearn.model_selection import train_test_split

from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, confusion_matrix, roc_curve, precision_recall_curve
from sklearn.utils.class_weight import compute_class_weight
from sklearn.svm import SVC

from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import LearningCurveDisplay, ShuffleSplit

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/ml files/updatedmuon.csv'

df = pd.read_csv(file_path)

print(df)
# Out:
#        collisionID  trackID     mcID      eta        pt          p      phi  \
# 0              111       -1    88367 -3.16496  0.243115   2.884550 -2.59080
# 1              111        0    88367  2.72339  0.115458   0.883115  6.49523
# 2              125       -1   102667 -3.41393  0.858880  13.062400  2.80120
# 3              125        2   102667 -3.43907  0.996715  15.543900  2.77976
# 4              168        5   133004 -2.81062  0.592036   4.937700 -2.29163
# ...            ...      ...      ...      ...       ...        ...      ...
# 88156         1694    11870  2165162 -2.53649  1.267230   8.056050 -1.19439
# 88157         1694    11870  2165162 -2.26606  2.343080  11.416700 -2.10517
# 88158         1694    11870  2165162 -2.20876  1.795700   8.273080 -1.53141
# 88159         1694    11870  2165162 -2.49586  1.298260   7.928870 -1.22032
# 88160         1694       -2  2168601 -2.99374  0.450407   4.506400 -1.57832
#
#        motherPDG  nClusters  trackType      pDca           chi2  \
# 0            211         11          3   76.7159       0.515625
# 1            211         11          0   76.7159  370688.000000
# 2            321         12          3   44.9307       0.144531
# 3            321         12          0   44.9307      37.000000
# 4            211         10          2   58.2282    1000.000000
# ...          ...        ...        ...       ...            ...
# 88156        411         10          0  110.6710    2768.000000
# 88157        411         10          0  110.6710   24960.000000
# 88158        411         10          0  110.6710     254.000000
# 88159        411         10          0  110.6710    1880.000000
# 88160        421          9          4   65.1975       0.128906
#
#        chi2MatchMCHMID     rabs  isPrompt   tracktime  sign
# 0             1.218750  28.8967         1   12.479266     1
# 1             1.218750  28.8967         1   12.479266    -1
# 2             0.554688  31.1311         1  286.939819     1
# 3             0.554688  31.1311         1  286.939819     1
# 4            -1.000000  45.7409         1  723.559570    -1
# ...                ...      ...       ...         ...   ...
# 88156         0.449219  81.7858         1 -212.064133    -1
# 88157         0.449219  81.7858         1 -212.064133     1
# 88158         0.449219  81.7858         1 -212.064133    -1
# 88159         0.449219  81.7858         1 -212.064133    -1
# 88160        -1.000000  58.4170         1  898.248352     1
#
# [88161 rows x 17 columns]

# %%
filter_df = df[(df['chi2'] <= 10)]
track_df = df[(df['trackType'] == 3)]
cut_df = track_df[(track_df['p'] > 4) & (track_df['eta'] >= -4) & (track_df['eta'] <= -2.5) & (track_df['pt'] > 0.5)] #consists of the chi2, track type & momentum cuts needed

# %%
cut_df.to_csv('cutsapplied(nochi2).csv', index=False)
cut_df.to_csv('/content/drive/MyDrive/ml files/cutsapplied.csv', index=False)

# %%
signalD = [abs(411), abs(421), abs(431), abs(4122), abs(4232), abs(4132)]
signalB = [abs(521), abs(511), abs(531), abs(5232), abs(5132), abs(5122)]
signalPDG = [abs(411), abs(421), abs(431), abs(4122), abs(4232), abs(4132), abs(521), abs(511), abs(531), abs(5232), abs(5132), abs(5122)]

# %%
focus_signal = "D"

label = []

for index, row in cut_df.iterrows():
    pdg = abs(row['motherPDG'])

    if focus_signal == "B":
        if pdg in signalB:
            label.append("s")   # B meson signal
        elif pdg in signalD:
            label.append("x")   # excluded (not background, not signal)
        else:
            label.append("b")   # background

    elif focus_signal == "D":
        if pdg in signalD:
            label.append("s")   # D meson signal
        elif pdg in signalB:
            label.append("x")   # excluded
        else:
            label.append("b")   # background

cut_df['label'] = label
# Out:
# /tmp/ipython-input-3433308258.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['label'] = label

# %%
cut_df
# Out:
#        collisionID  trackID     mcID      eta        pt         p       phi  \
# 2              125       -1   102667 -3.41393  0.858880  13.06240  2.801200
# 6              218       -1   171002 -2.93607  0.560673   5.29689  1.075610
# 8              252       -1   197209 -3.73895  0.510914  10.74910  0.096842
# 20             719       -5   540836 -3.46161  0.574716   9.16664 -0.345634
# 34             877       -5   657418 -2.95560  0.560175   5.39596  2.508450
# ...            ...      ...      ...      ...       ...       ...       ...
# 88090         1684       -2  2155308 -2.86598  0.821995   7.24307 -1.208640
# 88091         1684       -2  2155794 -3.73386  0.546972  11.44930  2.459840
# 88119         1688       -2  2159871 -3.51072  0.830579  13.91310 -1.892480
# 88125         1689       -2  2161464 -3.29699  0.758238  10.26200  1.238660
# 88143         1694       -2  2167180 -2.89710  0.872603   7.93056  0.819328
#
#        motherPDG  nClusters  trackType      pDca      chi2  chi2MatchMCHMID  \
# 2            321         12          3   44.9307  0.144531         0.554688
# 6            321         10          3  140.5290  0.210938         1.062500
# 8            321         10          3   51.1675  0.232422         1.304690
# 20           321         12          3  134.2360  0.092773         0.703125
# 34           211         10          3  105.3500  0.173828         1.203120
# ...          ...        ...        ...       ...       ...              ...
# 88090        411         10          3   16.0551  0.120605         0.894531
# 88091        421          9          3   40.6495  0.129883         0.511719
# 88119        431          7          3   30.4072  0.375000         0.585938
# 88125        431         14          3   59.5527  0.102539         1.593750
# 88143       4122         12          3   41.8271  0.080566         0.730469
#
#           rabs  isPrompt   tracktime  sign label
# 2      31.1311         1  286.939819     1     b
# 6      31.8958         1  736.044556    -1     b
# 8      26.5259         1  910.683838    -1     b
# 20     18.2902         1  611.293945     1     b
# 34     36.8680         0   12.463362    -1     b
# ...        ...       ...         ...   ...   ...
# 88090  56.2943         1   37.463413     1     s
# 88091  26.3077         1  910.650940    -1     s
# 88119  29.1006         1  486.548035     1     s
# 88125  33.4272         1  511.483124     1     s
# 88143  56.6216         1  187.123367    -1     s
#
# [10290 rows x 18 columns]

# %%
cut_df = cut_df[cut_df['label'] != 'x']

# %%
cut_df
# Out:
#        collisionID  trackID     mcID      eta        pt         p       phi  \
# 2              125       -1   102667 -3.41393  0.858880  13.06240  2.801200
# 6              218       -1   171002 -2.93607  0.560673   5.29689  1.075610
# 8              252       -1   197209 -3.73895  0.510914  10.74910  0.096842
# 20             719       -5   540836 -3.46161  0.574716   9.16664 -0.345634
# 34             877       -5   657418 -2.95560  0.560175   5.39596  2.508450
# ...            ...      ...      ...      ...       ...       ...       ...
# 88090         1684       -2  2155308 -2.86598  0.821995   7.24307 -1.208640
# 88091         1684       -2  2155794 -3.73386  0.546972  11.44930  2.459840
# 88119         1688       -2  2159871 -3.51072  0.830579  13.91310 -1.892480
# 88125         1689       -2  2161464 -3.29699  0.758238  10.26200  1.238660
# 88143         1694       -2  2167180 -2.89710  0.872603   7.93056  0.819328
#
#        motherPDG  nClusters  trackType      pDca      chi2  chi2MatchMCHMID  \
# 2            321         12          3   44.9307  0.144531         0.554688
# 6            321         10          3  140.5290  0.210938         1.062500
# 8            321         10          3   51.1675  0.232422         1.304690
# 20           321         12          3  134.2360  0.092773         0.703125
# 34           211         10          3  105.3500  0.173828         1.203120
# ...          ...        ...        ...       ...       ...              ...
# 88090        411         10          3   16.0551  0.120605         0.894531
# 88091        421          9          3   40.6495  0.129883         0.511719
# 88119        431          7          3   30.4072  0.375000         0.585938
# 88125        431         14          3   59.5527  0.102539         1.593750
# 88143       4122         12          3   41.8271  0.080566         0.730469
#
#           rabs  isPrompt   tracktime  sign label
# 2      31.1311         1  286.939819     1     b
# 6      31.8958         1  736.044556    -1     b
# 8      26.5259         1  910.683838    -1     b
# 20     18.2902         1  611.293945     1     b
# 34     36.8680         0   12.463362    -1     b
# ...        ...       ...         ...   ...   ...
# 88090  56.2943         1   37.463413     1     s
# 88091  26.3077         1  910.650940    -1     s
# 88119  29.1006         1  486.548035     1     s
# 88125  33.4272         1  511.483124     1     s
# 88143  56.6216         1  187.123367    -1     s
#
# [8408 rows x 18 columns]

# %%
l = cut_df['label']
l.value_counts()
# Out:
# label
# b    5485
# s    2923
# Name: count, dtype: int64

# %%
print(cut_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8408 entries, 2 to 88143
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   collisionID      8408 non-null   int64
#  1   trackID          8408 non-null   int64
#  2   mcID             8408 non-null   int64
#  3   eta              8408 non-null   float64
#  4   pt               8408 non-null   float64
#  5   p                8408 non-null   float64
#  6   phi              8408 non-null   float64
#  7   motherPDG        8408 non-null   int64
#  8   nClusters        8408 non-null   int64
#  9   trackType        8408 non-null   int64
#  10  pDca             8408 non-null   float64
#  11  chi2             8408 non-null   float64
#  12  chi2MatchMCHMID  8408 non-null   float64
#  13  rabs             8408 non-null   float64
#  14  isPrompt         8408 non-null   int64
#  15  tracktime        8408 non-null   float64
#  16  sign             8408 non-null   int64
#  17  label            8408 non-null   object
# dtypes: float64(9), int64(8), object(1)
# memory usage: 1.2+ MB
# None

# %%
cut_df['y'] = (cut_df["label"] == "s").astype(int)

y = cut_df['y'].to_numpy()
# Out:
# /tmp/ipython-input-3848919311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['y'] = (cut_df["label"] == "s").astype(int)

# %%
weight = compute_class_weight(class_weight="balanced", classes=np.unique(y), y=y)
print(weight)
# Out:
# [0.76645397 1.43824837]

# %%
cut_df['w'] = np.where(cut_df['y'] == 1, weight[1], weight[0])
w = cut_df['w']
# Out:
# /tmp/ipython-input-4139032214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cut_df['w'] = np.where(cut_df['y'] == 1, weight[1], weight[0])

# %%
w.value_counts()
# Out:
# w
# 0.766454    5485
# 1.438248    2923
# Name: count, dtype: int64

# %%
cut_df
# Out:
#        collisionID  trackID     mcID      eta        pt         p       phi  \
# 2              125       -1   102667 -3.41393  0.858880  13.06240  2.801200
# 6              218       -1   171002 -2.93607  0.560673   5.29689  1.075610
# 8              252       -1   197209 -3.73895  0.510914  10.74910  0.096842
# 20             719       -5   540836 -3.46161  0.574716   9.16664 -0.345634
# 34             877       -5   657418 -2.95560  0.560175   5.39596  2.508450
# ...            ...      ...      ...      ...       ...       ...       ...
# 88090         1684       -2  2155308 -2.86598  0.821995   7.24307 -1.208640
# 88091         1684       -2  2155794 -3.73386  0.546972  11.44930  2.459840
# 88119         1688       -2  2159871 -3.51072  0.830579  13.91310 -1.892480
# 88125         1689       -2  2161464 -3.29699  0.758238  10.26200  1.238660
# 88143         1694       -2  2167180 -2.89710  0.872603   7.93056  0.819328
#
#        motherPDG  nClusters  trackType      pDca      chi2  chi2MatchMCHMID  \
# 2            321         12          3   44.9307  0.144531         0.554688
# 6            321         10          3  140.5290  0.210938         1.062500
# 8            321         10          3   51.1675  0.232422         1.304690
# 20           321         12          3  134.2360  0.092773         0.703125
# 34           211         10          3  105.3500  0.173828         1.203120
# ...          ...        ...        ...       ...       ...              ...
# 88090        411         10          3   16.0551  0.120605         0.894531
# 88091        421          9          3   40.6495  0.129883         0.511719
# 88119        431          7          3   30.4072  0.375000         0.585938
# 88125        431         14          3   59.5527  0.102539         1.593750
# 88143       4122         12          3   41.8271  0.080566         0.730469
#
#           rabs  isPrompt   tracktime  sign label  y         w
# 2      31.1311         1  286.939819     1     b  0  0.766454
# 6      31.8958         1  736.044556    -1     b  0  0.766454
# 8      26.5259         1  910.683838    -1     b  0  0.766454
# 20     18.2902         1  611.293945     1     b  0  0.766454
# 34     36.8680         0   12.463362    -1     b  0  0.766454
# ...        ...       ...         ...   ...   ... ..       ...
# 88090  56.2943         1   37.463413     1     s  1  1.438248
# 88091  26.3077         1  910.650940    -1     s  1  1.438248
# 88119  29.1006         1  486.548035     1     s  1  1.438248
# 88125  33.4272         1  511.483124     1     s  1  1.438248
# 88143  56.6216         1  187.123367    -1     s  1  1.438248
#
# [8408 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Exclude columns not to be used as input features
FEATURE_EXCLUDE = ['trackType', 'motherPDG', 'mcID', 'trackID', 'collisionID', 'isPrompt', 'nClusters', 'sign' ,'label', 'y', 'w', 'chi2MatchMCHMID', 'chi2' ,'phi']
features = [c for c in cut_df.columns if c not in FEATURE_EXCLUDE]

# %%
x_raw = cut_df[features].copy()

# %%
x_raw
# Out:
#            eta        pt         p      pDca     rabs   tracktime
# 2     -3.41393  0.858880  13.06240   44.9307  31.1311  286.939819
# 6     -2.93607  0.560673   5.29689  140.5290  31.8958  736.044556
# 8     -3.73895  0.510914  10.74910   51.1675  26.5259  910.683838
# 20    -3.46161  0.574716   9.16664  134.2360  18.2902  611.293945
# 34    -2.95560  0.560175   5.39596  105.3500  36.8680   12.463362
# ...        ...       ...       ...       ...      ...         ...
# 88090 -2.86598  0.821995   7.24307   16.0551  56.2943   37.463413
# 88091 -3.73386  0.546972  11.44930   40.6495  26.3077  910.650940
# 88119 -3.51072  0.830579  13.91310   30.4072  29.1006  486.548035
# 88125 -3.29699  0.758238  10.26200   59.5527  33.4272  511.483124
# 88143 -2.89710  0.872603   7.93056   41.8271  56.6216  187.123367
#
# [8408 rows x 6 columns]

# %%
imputer = SimpleImputer(strategy="median")
x_imputed = imputer.fit_transform(x_raw)

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_imputed)

#xb_train, xb_test, yb_train, yb_test, wb_train, wb_test = train_test_split(xb_scaled, yb, wb, test_size=0.2, random_state=42, stratify=yb)

x_train, x_test, y_train, y_test, w_train, w_test = train_test_split(x_scaled, y, w, test_size=0.2, random_state=42, stratify=y)

print("Num features:", len(features))
x_train.shape, x_test.shape
# Out:
# Num features: 6
# ((6726, 6), (1682, 6))

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=25, random_state=42)
random_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=25, random_state=42)

# %%
importances = random_forest.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(10,6))
bars = plt.bar(range(x_raw.shape[1]), importances[indices], linewidth=1, color='darkorchid')

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f"{height:.2f}", ha="center", va="bottom", size=8)

plt.ylabel("Importance")
plt.xticks(range(x_raw.shape[1]), np.array(x_raw.columns)[indices], rotation=90, size=12)
# Out:
# ([<matplotlib.axis.XTick at 0x7b31c8f1a270>,
#   <matplotlib.axis.XTick at 0x7b31c8ef20c0>,
#   <matplotlib.axis.XTick at 0x7b31c8f1a090>,
#   <matplotlib.axis.XTick at 0x7b31c8d13d10>,
#   <matplotlib.axis.XTick at 0x7b31c8ce0320>,
#   <matplotlib.axis.XTick at 0x7b31c8ce0dd0>],
#  [Text(0, 0, 'p'),
#   Text(1, 0, 'pt'),
#   Text(2, 0, 'pDca'),
#   Text(3, 0, 'rabs'),
#   Text(4, 0, 'eta'),
#   Text(5, 0, 'tracktime')])

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers

keras.backend.clear_session()

def make_mlp(input_dim, hidden=[30, 30, 30, 30, 30], drop=0.2, l2=0.0):
    """
    Build a binary-classification MLP.

    Args:
        input_dim (int): number of input features (columns) after preprocessing.
        hidden (list[int]): how many neurons (units) to put in each hidden layer.
                            Example [256,128,64] means 3 hidden layers with those widths.
        drop (float): dropout rate (0.0–0.5 typical). Dropout randomly turns off a
                      fraction of neurons during training to reduce overfitting.
        l2 (float): L2 weight regularization strength (a small penalty on large weights).
                    Helps keep the model simpler and more generalizable.

    Returns:
        keras.Model: a compiled model ready to train with model.fit(...)
    """

    # ----- 1) Define the input “place holder” -----
    # Shape=(input_dim,) means the model expects a 1D vector of length input_dim for each row.
    inputs = keras.Input(shape=(input_dim,), name="features")

    # We'll wire layers onto this tensor "x". We start with x=inputs.
    x = inputs

    # ----- 2) Hidden layers (the actual “learning” happens here) -----
    # We loop over the list "hidden" so it’s easy to change depth/width from the function call.
    for i, h in enumerate(hidden, start=1):
        # Dense = fully connected layer. 'h' controls how many neurons (capacity).
        # activation='relu' is a standard nonlinearity that helps the network learn complex patterns.
        # kernel_regularizer adds the L2 penalty (weight decay) to fight overfitting.
        x = layers.Dense(
            h,
            activation="relu",
            kernel_regularizer=regularizers.l2(l2),
            name=f"dense_{i}"
        )(x)

        # Batch Normalization stabilizes and speeds up training by normalizing activations
        # inside the network (per mini-batch). This often allows slightly higher learning rates.
        x = layers.BatchNormalization(name=f"bn_{i}")(x)

        # Dropout randomly zeroes out a fraction `drop` of activations during training.
        # Think of it as creating slightly different sub-networks each step, which prevents
        # the model from relying too heavily on any single path (“co-adaptation”).
        x = layers.Dropout(drop, name=f"drop_{i}")(x)

    # ----- 3) Output layer -----
    # We have a **binary** classification problem (signal vs background),
    # so we produce ONE number in [0,1] using 'sigmoid'.
    # This can be interpreted as P(y=1 | x) = probability of signal.
    outputs = layers.Dense(1, activation="sigmoid", name="logit")(x)

    # ----- 4) Build the model graph -----
    model = keras.Model(inputs, outputs, name="mlp_higgs")

    # ----- 5) Choose optimizer, loss, and metrics -----
    # Optimizer: Adam is a good default that adapts the learning rate during training.
    # Loss: binary cross-entropy is the standard for binary classification.
    # Metrics:
    #   - AUC (ROC-AUC): threshold-free measure of ranking quality.
    #   - Precision & Recall: computed at a default threshold (0.5) — useful but threshold-dependent.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.AUC(name="auc"),
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall"),
        ],
    )

    return model

# ----- 6) Create the model -----
# X_train.shape[1] is “how many feature columns do we have?”
# We use 3 hidden layers with widths 256 → 128 → 64, 20% dropout, tiny L2 penalty.
mlp = make_mlp(
    input_dim=x_train.shape[1],
    hidden=[30, 30, 30, 30, 30],
    drop=0.2,
    l2=1e-6
)

# Show a summary table of the layers, shapes, and parameter counts.
mlp.summary()
# Out:
# Model: "mlp_higgs"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ features (InputLayer)           │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 30)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_1 (Dropout)                │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 30)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_2 (Dropout)                │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_3 (BatchNormalization)       │ (None, 30)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_3 (Dropout)                │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_4 (BatchNormalization)       │ (None, 30)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_4 (Dropout)                │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_5 (BatchNormalization)       │ (None, 30)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_5 (Dropout)                │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ logit (Dense)                   │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,561 (17.82 KB)
#  Trainable params: 4,261 (16.64 KB)
#  Non-trainable params: 300 (1.17 KB)

# %%
history = mlp.fit(
    x_train, y_train,
    sample_weight=w_train,              # <-- important: use sample weights
    validation_data=(x_test, y_test, w_test),
    epochs=50,
    batch_size=100,
    verbose=1
)
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - auc: 0.5704 - loss: 0.7686 - precision: 0.3820 - recall: 0.5991 - val_auc: 0.6560 - val_loss: 0.6776 - val_precision: 0.5029 - val_recall: 0.4479
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6408 - loss: 0.6846 - precision: 0.4404 - recall: 0.6110 - val_auc: 0.6992 - val_loss: 0.6497 - val_precision: 0.5161 - val_recall: 0.5744
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6415 - loss: 0.6788 - precision: 0.4378 - recall: 0.6034 - val_auc: 0.7096 - val_loss: 0.6279 - val_precision: 0.5205 - val_recall: 0.5863
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.6778 - loss: 0.6538 - precision: 0.4693 - recall: 0.6472 - val_auc: 0.7139 - val_loss: 0.6176 - val_precision: 0.5353 - val_recall: 0.5709
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.6733 - loss: 0.6546 - precision: 0.4759 - recall: 0.6072 - val_auc: 0.7256 - val_loss: 0.6103 - val_precision: 0.5120 - val_recall: 0.6205
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6917 - loss: 0.6438 - precision: 0.4898 - recall: 0.6477 - val_auc: 0.7273 - val_loss: 0.6086 - val_precision: 0.5239 - val_recall: 0.6188
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7016 - loss: 0.6278 - precision: 0.4939 - recall: 0.6465 - val_auc: 0.7266 - val_loss: 0.6073 - val_precision: 0.5166 - val_recall: 0.6393
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.7032 - loss: 0.6259 - precision: 0.4865 - recall: 0.6448 - val_auc: 0.7255 - val_loss: 0.6083 - val_precision: 0.5139 - val_recall: 0.6342
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.6972 - loss: 0.6307 - precision: 0.4868 - recall: 0.6324 - val_auc: 0.7256 - val_loss: 0.6085 - val_precision: 0.5115 - val_recall: 0.6462
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - auc: 0.7075 - loss: 0.6254 - precision: 0.4931 - recall: 0.6521 - val_auc: 0.7266 - val_loss: 0.6081 - val_precision: 0.5039 - val_recall: 0.6564
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - auc: 0.7142 - loss: 0.6177 - precision: 0.4870 - recall: 0.6756 - val_auc: 0.7252 - val_loss: 0.6090 - val_precision: 0.5013 - val_recall: 0.6701
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - auc: 0.7192 - loss: 0.6230 - precision: 0.5145 - recall: 0.6775 - val_auc: 0.7266 - val_loss: 0.6080 - val_precision: 0.5026 - val_recall: 0.6547
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - auc: 0.7254 - loss: 0.6135 - precision: 0.5082 - recall: 0.6785 - val_auc: 0.7277 - val_loss: 0.6074 - val_precision: 0.5116 - val_recall: 0.6410
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7085 - loss: 0.6256 - precision: 0.4984 - recall: 0.6394 - val_auc: 0.7294 - val_loss: 0.6061 - val_precision: 0.5207 - val_recall: 0.6462
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7348 - loss: 0.6077 - precision: 0.5207 - recall: 0.6650 - val_auc: 0.7297 - val_loss: 0.6049 - val_precision: 0.5006 - val_recall: 0.6667
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7114 - loss: 0.6239 - precision: 0.4937 - recall: 0.6586 - val_auc: 0.7309 - val_loss: 0.6040 - val_precision: 0.5178 - val_recall: 0.6479
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7159 - loss: 0.6199 - precision: 0.5117 - recall: 0.6514 - val_auc: 0.7322 - val_loss: 0.6032 - val_precision: 0.5130 - val_recall: 0.6410
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7285 - loss: 0.6147 - precision: 0.5162 - recall: 0.6649 - val_auc: 0.7315 - val_loss: 0.6035 - val_precision: 0.5166 - val_recall: 0.6393
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7264 - loss: 0.6148 - precision: 0.5188 - recall: 0.6712 - val_auc: 0.7323 - val_loss: 0.6029 - val_precision: 0.5108 - val_recall: 0.6496
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7366 - loss: 0.6075 - precision: 0.5274 - recall: 0.6730 - val_auc: 0.7329 - val_loss: 0.6027 - val_precision: 0.5071 - val_recall: 0.6718
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7299 - loss: 0.6037 - precision: 0.4952 - recall: 0.6624 - val_auc: 0.7316 - val_loss: 0.6031 - val_precision: 0.5086 - val_recall: 0.6581
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7288 - loss: 0.6043 - precision: 0.4978 - recall: 0.6690 - val_auc: 0.7319 - val_loss: 0.6033 - val_precision: 0.5146 - val_recall: 0.6342
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7199 - loss: 0.6197 - precision: 0.5110 - recall: 0.6614 - val_auc: 0.7330 - val_loss: 0.6029 - val_precision: 0.5059 - val_recall: 0.6598
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7237 - loss: 0.6151 - precision: 0.5093 - recall: 0.6835 - val_auc: 0.7315 - val_loss: 0.6042 - val_precision: 0.5171 - val_recall: 0.6462
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7253 - loss: 0.6149 - precision: 0.5167 - recall: 0.6690 - val_auc: 0.7321 - val_loss: 0.6046 - val_precision: 0.5079 - val_recall: 0.6632
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7432 - loss: 0.5999 - precision: 0.5313 - recall: 0.6902 - val_auc: 0.7326 - val_loss: 0.6040 - val_precision: 0.5128 - val_recall: 0.6530
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7390 - loss: 0.6057 - precision: 0.5280 - recall: 0.6698 - val_auc: 0.7316 - val_loss: 0.6041 - val_precision: 0.5098 - val_recall: 0.6667
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7328 - loss: 0.6056 - precision: 0.5111 - recall: 0.6686 - val_auc: 0.7321 - val_loss: 0.6042 - val_precision: 0.5112 - val_recall: 0.6650
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7351 - loss: 0.6060 - precision: 0.5225 - recall: 0.6577 - val_auc: 0.7321 - val_loss: 0.6041 - val_precision: 0.5140 - val_recall: 0.6581
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7310 - loss: 0.6082 - precision: 0.5221 - recall: 0.6772 - val_auc: 0.7327 - val_loss: 0.6037 - val_precision: 0.5193 - val_recall: 0.6444
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7308 - loss: 0.6078 - precision: 0.5095 - recall: 0.6597 - val_auc: 0.7323 - val_loss: 0.6039 - val_precision: 0.5128 - val_recall: 0.6496
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7287 - loss: 0.6117 - precision: 0.5080 - recall: 0.6762 - val_auc: 0.7320 - val_loss: 0.6043 - val_precision: 0.5135 - val_recall: 0.6513
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.7257 - loss: 0.6083 - precision: 0.5096 - recall: 0.6502 - val_auc: 0.7322 - val_loss: 0.6040 - val_precision: 0.5106 - val_recall: 0.6615
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.7331 - loss: 0.6061 - precision: 0.5099 - recall: 0.6959 - val_auc: 0.7320 - val_loss: 0.6039 - val_precision: 0.5071 - val_recall: 0.6735
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.7395 - loss: 0.6031 - precision: 0.5264 - recall: 0.6893 - val_auc: 0.7313 - val_loss: 0.6044 - val_precision: 0.5251 - val_recall: 0.6444
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.7361 - loss: 0.6047 - precision: 0.5278 - recall: 0.6771 - val_auc: 0.7324 - val_loss: 0.6034 - val_precision: 0.5125 - val_recall: 0.6632
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.7344 - loss: 0.6029 - precision: 0.5155 - recall: 0.6734 - val_auc: 0.7324 - val_loss: 0.6039 - val_precision: 0.5105 - val_recall: 0.6667
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7395 - loss: 0.5990 - precision: 0.5153 - recall: 0.6672 - val_auc: 0.7332 - val_loss: 0.6028 - val_precision: 0.5117 - val_recall: 0.6701
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7273 - loss: 0.6085 - precision: 0.4985 - recall: 0.6645 - val_auc: 0.7335 - val_loss: 0.6027 - val_precision: 0.5137 - val_recall: 0.6718
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7250 - loss: 0.6122 - precision: 0.4976 - recall: 0.6693 - val_auc: 0.7338 - val_loss: 0.6028 - val_precision: 0.5132 - val_recall: 0.6632
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7302 - loss: 0.6050 - precision: 0.5004 - recall: 0.6721 - val_auc: 0.7333 - val_loss: 0.6028 - val_precision: 0.5120 - val_recall: 0.6581
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7383 - loss: 0.6012 - precision: 0.5151 - recall: 0.6745 - val_auc: 0.7327 - val_loss: 0.6032 - val_precision: 0.5120 - val_recall: 0.6564
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7254 - loss: 0.6104 - precision: 0.5066 - recall: 0.6545 - val_auc: 0.7332 - val_loss: 0.6032 - val_precision: 0.5156 - val_recall: 0.6496
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7391 - loss: 0.5999 - precision: 0.5228 - recall: 0.6683 - val_auc: 0.7341 - val_loss: 0.6025 - val_precision: 0.5039 - val_recall: 0.6564
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7316 - loss: 0.6067 - precision: 0.5100 - recall: 0.6659 - val_auc: 0.7344 - val_loss: 0.6023 - val_precision: 0.5059 - val_recall: 0.6632
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7251 - loss: 0.6080 - precision: 0.5014 - recall: 0.6704 - val_auc: 0.7343 - val_loss: 0.6027 - val_precision: 0.5040 - val_recall: 0.6513
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7370 - loss: 0.6003 - precision: 0.5096 - recall: 0.6786 - val_auc: 0.7329 - val_loss: 0.6030 - val_precision: 0.5077 - val_recall: 0.6769
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7354 - loss: 0.6016 - precision: 0.5054 - recall: 0.6715 - val_auc: 0.7333 - val_loss: 0.6031 - val_precision: 0.5154 - val_recall: 0.6581
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.7446 - loss: 0.5996 - precision: 0.5299 - recall: 0.6991 - val_auc: 0.7335 - val_loss: 0.6034 - val_precision: 0.5264 - val_recall: 0.6479
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7448 - loss: 0.5956 - precision: 0.5415 - recall: 0.6800 - val_auc: 0.7338 - val_loss: 0.6023 - val_precision: 0.5274 - val_recall: 0.6410

# %%
h = history.history
plt.figure(figsize=(6,4))
plt.plot(h['auc'], label='train accuracy')
plt.plot(h['val_auc'], label='test accuracy')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()

plt.figure(figsize=(6,4))
plt.plot(h['loss'], label='train loss')
plt.plot(h['val_loss'], label='test loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# %%
#WITH WEIGHTS

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, accuracy_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score

proba_test_nn = mlp.predict(x_test, batch_size=2048).ravel()
pred_test_nn_05 = (proba_test_nn >= 0.5).astype(int)


metrics_nn_weighted = {
    "Accuracy": accuracy_score(y_test, pred_test_nn_05, sample_weight= w_test),
    "F1": f1_score(y_test, pred_test_nn_05, sample_weight=w_test),
    "ROC_AUC": roc_auc_score(y_test, proba_test_nn, sample_weight=w_test),
    "ConfusionMatrix": confusion_matrix(y_test, pred_test_nn_05, sample_weight=w_test)
}
metrics_nn_weighted
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# {'Accuracy': 0.6673588707917502,
#  'F1': 0.6584393558746549,
#  'ROC_AUC': np.float64(0.7336325175887595),
#  'ConfusionMatrix': array([[583.27146764, 257.52853236],
#         [302.03215874, 539.34314061]])}

# %%
# ROC
fpr, tpr, thresholds = roc_curve(y_test, proba_test_nn, sample_weight= w_test)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"ROC AUC (area = {roc_auc_score(y_test, proba_test_nn, sample_weight= w_test):.3f})")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.legend(); plt.show()

# PR
prec, rec, thr = precision_recall_curve(y_test, proba_test_nn, sample_weight= w_test)
plt.figure(figsize=(6,5))
plt.plot(rec, prec)
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.show()

print("Weighted confusion matrix (threshold=0.5):\n", metrics_nn_weighted["ConfusionMatrix"])
# Out:
# Weighted confusion matrix (threshold=0.5):
#  [[583.27146764 257.52853236]
#  [302.03215874 539.34314061]]

# %%
signal = proba_test_nn[y_test == 1]
background = proba_test_nn[y_test == 0]

plt.figure(figsize=(8,6))
bins = np.linspace(0, 1, 40)

plt.axvline(0.5, color='gray', linestyle='--', linewidth=1)

plt.hist(signal, bins=100, density=True, alpha=0.5, label='Signal (label = 1)', color='indigo')
plt.hist(background, bins=100, density=True, alpha=0.5, label='Background (label = 0)', color='limegreen')

plt.xlabel('Predicted Probability')
plt.ylabel('Density')
plt.legend()
#plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
cmweighted = confusion_matrix(y_test, pred_test_nn_05, sample_weight=w_test)

tn, fp, fn, tp = cmweighted.ravel()

print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Positives (TP): {tp}")


cm_percent_weight = cmweighted / cmweighted.sum()

labels = np.array([["{0:.2f}\n{1:.1%}".format(value, cm_percent_weight[i, j])
                    for j, value in enumerate(row)] for i, row in enumerate(cmweighted)])

plt.figure(figsize=(6,5))
sns.heatmap(cmweighted, annot=labels, fmt="", cmap="Purples", cbar=True,
            xticklabels=["Predicted 0","Predicted 1"],
            yticklabels=["True 0","True 1"])

plt.ylabel("True")
plt.xlabel("Predicted")
plt.show()
# Out:
# True Negatives (TN): 583.2714676390175
# False Positives (FP): 257.5285323609864
# False Negatives (FN): 302.0321587410194
# True Positives (TP): 539.3431406089652

# %%
precision = precision_score(y_test, pred_test_nn_05)
recall = recall_score(y_test, pred_test_nn_05)

print(recall)
print(precision)
# Out:
# 0.6410256410256411
# 0.5274261603375527

# %%
#WITHOUT WEIGHTS

# %%
metrics_unweighted = {
    "Accuracy": accuracy_score(y_test, pred_test_nn_05),
    "F1": f1_score(y_test, pred_test_nn_05),
    "ROC_AUC": roc_auc_score(y_test, proba_test_nn),
    "ConfusionMatrix": confusion_matrix(y_test, pred_test_nn_05)
}
metrics_unweighted
# Out:
# {'Accuracy': 0.6753864447086801,
#  'F1': 0.5787037037037037,
#  'ROC_AUC': np.float64(0.7336325175887619),
#  'ConfusionMatrix': array([[761, 336],
#         [210, 375]])}

# %%
# ROC
fpr, tpr, thresholds = roc_curve(y_test, proba_test_nn)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"ROC AUC (area = {roc_auc_score(y_test, proba_test_nn):.3f})")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.legend(); plt.show()

# PR
prec, rec, thr = precision_recall_curve(y_test, proba_test_nn)
plt.figure(figsize=(6,5))
plt.plot(rec, prec)
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.show()

print("Unweighted confusion matrix (threshold=0.5):\n", metrics_unweighted["ConfusionMatrix"])
# Out:
# Unweighted confusion matrix (threshold=0.5):
#  [[761 336]
#  [210 375]]

# %%
cm = confusion_matrix(y_test, pred_test_nn_05)

tn, fp, fn, tp = cm.ravel()

print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Positives (TP): {tp}")


cm_percent = cm / cm.sum()

labels = np.array([["{0:.2f}\n{1:.1%}".format(value, cm_percent[i, j])
                    for j, value in enumerate(row)] for i, row in enumerate(cm)])

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=labels, fmt="", cmap="Purples", cbar=True,
            xticklabels=["Predicted 0","Predicted 1"],
            yticklabels=["True 0","True 1"])


plt.ylabel("True")
plt.xlabel("Predicted")
plt.show()
# Out:
# True Negatives (TN): 761
# False Positives (FP): 336
# False Negatives (FN): 210
# True Positives (TP): 375
